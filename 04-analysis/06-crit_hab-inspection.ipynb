# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from nfw_project import config_paths as cfg
from pathlib import Path

# %%
crit_hab = gpd.read_file(cfg.ROADLESS_ANALYSIS_GPKG, layer="crithab_poly_ra")

# %%
crit_hab.columns
# Out:
# Index(['singlmulti', 'comname', 'sciname', 'spcode', 'vipcode', 'entity_id',
#        'unit', 'subunit', 'unitname', 'subunitnam', 'status', 'leadoffice',
#        'coopoffice', 'coopofmore', 'fedreg', 'pubdate', 'effectdate',
#        'vacatedate', 'accuracy', 'source_id', 'OBJECTID_1', 'listing_st',
#        'geometry'],
#       dtype='object')

# %%
unique_comname = crit_hab['comname'].unique()
unique_sciname = crit_hab['sciname'].unique()
print("Unique comname:", unique_comname)
print("Unique sciname:", unique_sciname)
# Out:
# Unique comname: ['Foothill yellow-legged frog' 'Western Snowy Plover'
#  'Narrow-headed gartersnake' 'Triangular Kidneyshell' 'Loach minnow'
#  'California condor' 'Purple amole' 'Yellow-billed Cuckoo'
#  'Gunnison Sage-grouse' 'Heliotrope milk-vetch' 'Little Kern golden Trout'
#  "Preble's meadow jumping mouse" 'Quino checkerspot butterfly'
#  'Conservancy fairy shrimp' 'Slender Orcutt grass' 'Lost River sucker'
#  'Shortnose Sucker' "Greene's tuctoria" 'Finelined pocketbook'
#  'Jemez Mountains salamander' 'Mountain yellow-legged frog' 'Indiana bat'
#  'Hermes copper butterfly'
#  'Pacific Marten, Coastal Distinct Population Segment'
#  'Laguna Mountains skipper' 'Frosted Flatwoods salamander' 'Canada Lynx'
#  'Sierra Nevada bighorn sheep' 'Southern Mountain Caribou DPS'
#  'Chiricahua leopard frog' "Taylor's (=whulge) Checkerspot"
#  'Greater sage-grouse' 'Little Colorado spinedace' 'Mexican spotted owl'
#  'Mount Graham red squirrel' 'Southwestern willow flycatcher' 'Jaguar'
# ...
